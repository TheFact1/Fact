# %%
import pickle
from datetime import datetime

import sqlalchemy as sa
from db import session_scope
from db.news import News

# from src_news.CNBC_parser import CNBC_parser
# from src_news.RBC_parser import RBC_parser

# active_parsers=[CNBC_parser(),RBC_parser()]
# active_parsers=[RBC_parser()]



## write
# with open('active_parsers.pkl', 'wb') as fp:
#     pickle.dump(active_parsers,fp)

print("writed pickle")

# read
with open("active_parsers.pkl", "rb") as fp:
    active_parsers = pickle.load(fp)

# if __name__ == "__main__":
#     for obj_websites in active_parsers:
#         for capsula in obj_websites.set_sapsules_news.get_set_capsules():
#             # capsula = obj_websites.set_sapsules_news.get_set_capsules()[1]
#             print("type(news_capsule)", type(capsula))
#             print("\n")
#             print("capsula.link: ", capsula.link, "\n")
#             print("capsula.title", capsula.title, "\n")
#             print("capsula.article_text", capsula.article_text, "\n")
#             print("capsula.image_link", capsula.image_link, "\n")
#             print("capsula.category", capsula.category, "\n")
#             print("capsula.dtime", capsula.dtime, "\n")
#             print("capsula.dtime", type(capsula.dtime), "\n")
#             print("\n \n \n")

#             with session_scope() as s:
#                 query = sa.insert(News).values(
#                     platform_id=1,
#                     link=capsula.link,
#                     title=capsula.title,
#                     content=capsula.article_text,
#                     image=capsula.image_link,
#                     category="Bitcoin",
#                     created_on=datetime.now(),  # capsula.unix_time
#                 )
#                 s.execute(query)
# Out:
# writed pickle

# %%
if __name__ == "__main__":
    for obj_websites in active_parsers:
        for capsula in obj_websites.set_sapsules_news.get_set_capsules():
            # capsula = obj_websites.set_sapsules_news.get_set_capsules()[1]
            print("type(news_capsule)", type(capsula))
            print("\n")
            print("capsula.link: ", capsula.link, "\n")
            print("capsula.title", capsula.title, "\n")
            print("capsula.article_text", capsula.article_text, "\n")
            print("capsula.image_link", capsula.image_link, "\n")
            print("capsula.category", capsula.category, "\n")
            print("capsula.dtime", capsula.dtime, "\n")
            print("capsula.dtime", type(capsula.dtime), "\n")
            print("\n \n \n")
# Out:
# type(news_capsule) <class 'utils.utils.Capsule_news'>
#
#
# capsula.link:  https://www.cnbc.com/video/2022/09/01/bitcoin-20000-dc-sues-saylor-nifty-gateway-nft-features-crypto-world.html
#
# capsula.title Bitcoin dips below $20,000, D.C. sues Saylor, and Nifty Gateway's new NFT features: CNBC Crypto World
#
# capsula.article_text CNBC Crypto World features the latest news and daily trading updates from the digital currency markets and provides viewers with a look at what's ahead with high-profile interviews, explainers, and unique stories from the ever-changing crypto industry. On today's show, Jake Boyle of Caleb & Brown discusses crypto markets and what investors should watch for the rest of 2022.
#
# capsula.image_link https://image.cnbcfm.com/api/v1/image/107112826-090122_CW_Thumb_fixed.jpg?v=1662058976&w=750&h=422&vtcrop=y
#
# capsula.category
#
# capsula.dtime 2022-09-01 10:00:00
#
# capsula.dtime <class 'datetime.datetime'>
#
#
#
#
#
# ...

# %%
len(active_parsers[1].set_sapsules_news.get_set_capsules())
# Out:
# 9

# %%
a="https://www.cnbc.com/video/2022/06/30/bitcoin-19000-sec-rejects-spot-etf-ftx-nears-deal-blockfi-crypto-world.html"
exists = db.session.query(User.id).filter_by(name='davidism').first() is not None

# %%
        users = (
            s.query(Users)
            .filter(
                Users.username == username,
            )
            .all()
        )

# %%
a="https://www.cnbc.com/video/2022/06/30/bitcoin-19000-sec-rejects-spot-etf-ftx-nears-deal-blockfi-crypto-world.htmla"

with session_scope() as s:
    users = (
        s.query(News)
        .filter(
            News.link == a,
        )
        .first()
        )

# %%
users==None
# Out:
# True
